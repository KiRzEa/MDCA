# %%
# !git clone https://github.com/KiRzEa/MDCA.git
# Out:
# Cloning into 'MDCA'...
# remote: Enumerating objects: 78, done.
# remote: Counting objects: 100% (78/78), done.
# remote: Compressing objects: 100% (78/78), done.
# remote: Total 78 (delta 37), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (78/78), 3.73 MiB | 3.79 MiB/s, done.

# %%
# %cd ./MDCA
# !git pull
# Out:
# /kaggle/working/MDCA
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 3 (delta 2), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (3/3), 941 bytes | 941.00 KiB/s, done.
# From https://github.com/KiRzEa/MDCA
#    29bf70c..851d956  main       -> origin/main
# Updating 29bf70c..851d956
# Fast-forward
#  dataset.py | 4 ++--
#  1 file changed, 2 insertions(+), 2 deletions(-)

# %%
from huggingface_hub import snapshot_download
snapshot_download(repo_id="facebook/bart-large-cnn", local_dir="./pretrained/bart-large-cnn")

# from huggingface_hub import snapshot_download
# snapshot_download(repo_id="google/flan-t5-base", local_dir="./pretrained/flan-t5-base")
# Out:
# Fetching 13 files:   0%|          | 0/13 [00:00<?, ?it/s]
# generation_config_for_summarization.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.58k [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/6.01k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# .gitattributes:   0%|          | 0.00/445 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# tf_model.h5:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# flax_model.msgpack:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# rust_model.ot:   0%|          | 0.00/2.04G [00:00<?, ?B/s]
# '/kaggle/working/MDCA/pretrained/bart-large-cnn'

# %%
# !pip install gdown --quiet
# !gdown 'https://drive.google.com/uc?export=download&id=1LDfA8WqmZHdPiTX1IvgrhJ3_52CRPs4v' -O tweet2015.zip
# !gdown 'https://drive.google.com/uc?export=download&id=1oMwK7nQcz1VrjyZO1Ecf9SiYs8EMUPcG' -O tweet2017.zip
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?export=download&id=1LDfA8WqmZHdPiTX1IvgrhJ3_52CRPs4v
# From (redirected): https://drive.google.com/uc?export=download&id=1LDfA8WqmZHdPiTX1IvgrhJ3_52CRPs4v&confirm=t&uuid=127f7406-ea27-4716-bc7e-4b0cd914ecac
# To: /kaggle/working/tweet2015.zip
# 100%|██████████████████████████████████████| 1.97G/1.97G [02:45<00:00, 11.9MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?export=download&id=1oMwK7nQcz1VrjyZO1Ecf9SiYs8EMUPcG
# From (redirected): https://drive.google.com/uc?export=download&id=1oMwK7nQcz1VrjyZO1Ecf9SiYs8EMUPcG&confirm=t&uuid=8e07e3c1-0045-453a-b4eb-64d52cb987ee
# To: /kaggle/working/tweet2017.zip
# 100%|██████████████████████████████████████| 1.63G/1.63G [02:27<00:00, 11.0MB/s]

# %%
# %cd /kaggle/working/
# !unzip -q tweet2015.zip -d MDCA/data/twitter2015
# !unzip -q tweet2017.zip -d MDCA/data/twitter2017
# %cd /kaggle/working/MDCA
# Out:
# /kaggle/working
# /kaggle/working/MDCA

# %%
# !python run_bart.py --dataset_name twitter2017 --num_train_epochs 2
# Out:
# /opt/conda/lib/python3.10/site-packages/transformers/generation/configuration_utils.py:563: UserWarning: `num_beams` is set to 1. However, `early_stopping` is set to `True` -- this flag is only used in beam-based generation modes. You should set `num_beams>1` or unset `early_stopping`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/transformers/generation/configuration_utils.py:563: UserWarning: `num_beams` is set to 1. However, `early_stopping` is set to `True` -- this flag is only used in beam-based generation modes. You should set `num_beams>1` or unset `early_stopping`.
#   warnings.warn(
# ...

# %%
with open('checkpoints/MDCA-BART/eval_results.txt') as f:
    print(f.read())
# Out:
# ***** Eval results *****#the result of a_results
#   acc = 0.7312925170068028
#   f1 = 0.7277062563967068
#
# #the result of ea_results
#   acc = 0.6547619047619048
#   f1 = 0.6121678775393047
#
# #the result of iea_results
#
# #the result of avg_results
#   acc = 0.6930272108843538
#   f1 = 0.6699370669680058
#
# ***** Test results *****#the result of a_results
#   acc = 0.7325769854132901
#   f1 = 0.7243117624370091
#
# #the result of ea_results
#   acc = 0.6839546191247974
#   f1 = 0.631872329105183
#
# #the result of iea_results
#
# #the result of avg_results
#   acc = 0.7082658022690438
#   f1 = 0.678092045771096
#
# ***** Eval results *****#the result of a_results
#   acc = 0.7534013605442177
#   f1 = 0.7372007560687045
#
# #the result of ea_results
#   acc = 0.6615646258503401
#   f1 = 0.6223859390421872
#
# #the result of avg_results
#   acc = 0.7074829931972789
#   f1 = 0.6797933475554458
#
# ***** Test results *****#the result of a_results
#   acc = 0.7382495948136143
# ...
